# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !pip install lets-plot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lets-plot
#   Downloading lets_plot-2.5.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 5.1 MB/s
# Collecting pypng
#   Downloading pypng-0.20220715.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.1 MB/s
# Requirement already satisfied: palettable in /usr/local/lib/python3.7/dist-packages (from lets-plot) (3.3.0)
# Installing collected packages: pypng, lets-plot
# Successfully installed lets-plot-2.5.1 pypng-0.20220715.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import lets_plot as lp
import seaborn as sns

sns.set()
lp.LetsPlot.setup_html()

# %% [markdown]
# ## Experiment 1 - How to determine P(H)?
#
# Maybe we can try flipping the coin many times. Then:
#
# \begin{equation}
# P(H) = \frac{\text{num(Heads)}}{\text{num(coin tosses)}}
# \end{equation}
#
# Let's try an experiment with this.

# %% [markdown]
# #### First, we 'choose' a coin. For this, we pick a random probability value

# %%
p_heads = np.random.beta(2, 4)

# %% [markdown]
# #### Without knowing what this value is, let's try to guess it with experiments

# %%
num_tosses = 100
num_heads = 0

for i in range(num_tosses):
    toss_result = np.random.choice(["H", "T"], p=[p_heads, 1 - p_heads])

    if toss_result == "H":
        num_heads = num_heads + 1

p_guess = num_heads / num_tosses

# %%
lp.ggplot(
    data=pd.DataFrame(
        dict(value=[p_heads, p_guess], prob=["True P(H)", "Guessed P(H)"])
    )
) + lp.geom_bar(lp.aes(x="prob", y="value", fill="prob"), stat="identity")
# Out:
# <html lang="en">
#    <head>
#        <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.5.1/js-package/distr/lets-plot.min.js"></script>
#    </head>
#    <body>
#           <div id="StSFfI"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        var plotSpec={
# "data":{
# "value":[0.07917212523895374,0.07],
# "prob":["True P(H)","Guessed P(H)"]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"prob",
# "y":"value",
# "fill":"prob"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#        var plotContainer = document.getElementById("StSFfI");
#        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#    </script>
#    </body>
# </html>

# %% [markdown]
# #### So, 100 tosses gets us close! But not quite there
#
# #### Will we always guess the same value for P(H)?
#
# - With the same number of tosses?
# - What if we change the number of tosses? Very large number of tosses? What about very few?

# %% [markdown]
# ## Experiment 2: Repeated Guessing
#
# Let's retry the experiment above, 500 times.

# %%
num_retries = 500
num_tosses = 100

tosses = pd.DataFrame(
    np.random.choice(
        ["H", "T"], size=(num_retries, num_tosses), p=[p_heads, 1 - p_heads]
    ),
    columns=[f"Toss {i}" for i in range(1, num_tosses + 1)],
    index=[f"Try #{i}" for i in range(1, num_retries + 1)],
)

# %%
tosses
# Out:
#          Toss 1 Toss 2 Toss 3 Toss 4 Toss 5 Toss 6 Toss 7 Toss 8 Toss 9  \
# Try #1        T      T      H      T      T      T      T      T      T
# Try #2        T      T      T      T      T      H      T      T      T
# Try #3        T      T      T      T      T      T      H      T      T
# Try #4        T      T      T      T      T      H      T      T      T
# Try #5        T      T      T      T      T      T      T      T      T
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# Try #496      T      T      T      T      T      T      T      T      T
# Try #497      H      T      T      T      T      T      T      T      T
# Try #498      T      T      T      T      T      T      T      T      T
# Try #499      H      T      T      H      T      T      T      T      T
# Try #500      T      T      T      T      T      T      T      T      T
#
#          Toss 10  ... Toss 91 Toss 92 Toss 93 Toss 94 Toss 95 Toss 96 Toss 97  \
# Try #1         T  ...       T       T       T       T       T       T       T
# Try #2         T  ...       T       T       T       T       T       T       T
# Try #3         T  ...       T       T       T       T       T       T       T
# Try #4         T  ...       T       T       T       T       T       T       T
# Try #5         T  ...       T       T       T       T       H       T       H
# ...          ...  ...     ...     ...     ...     ...     ...     ...     ...
# Try #496       T  ...       T       T       T       T       T       T       T
# Try #497       T  ...       T       T       T       T       T       T       T
# Try #498       H  ...       T       T       T       T       H       T       T
# Try #499       H  ...       T       H       T       T       T       T       T
# Try #500       T  ...       T       T       T       T       T       T       T
#
#          Toss 98 Toss 99 Toss 100
# Try #1         T       T        T
# Try #2         T       T        T
# Try #3         H       T        T
# Try #4         T       T        H
# Try #5         T       T        T
# ...          ...     ...      ...
# Try #496       T       T        T
# Try #497       H       T        H
# Try #498       T       T        T
# Try #499       T       T        T
# Try #500       T       T        T
#
# [500 rows x 100 columns]

# %%
guesses = (tosses == "H").sum(axis=1).to_frame("Number of Heads")
guesses
# Out:
#           Number of Heads
# Try #1                  7
# Try #2                  6
# Try #3                  9
# Try #4                  9
# Try #5                  7
# ...                   ...
# Try #496               11
# Try #497               10
# Try #498                9
# Try #499               14
# Try #500               10
#
# [500 rows x 1 columns]

# %%
guesses["Guessed P(H)"] = guesses["Number of Heads"] / num_tosses

# %%
guesses
# Out:
#           Number of Heads  Guessed P(H)
# Try #1                  7          0.07
# Try #2                  6          0.06
# Try #3                  9          0.09
# Try #4                  9          0.09
# Try #5                  7          0.07
# ...                   ...           ...
# Try #496               11          0.11
# Try #497               10          0.10
# Try #498                9          0.09
# Try #499               14          0.14
# Try #500               10          0.10
#
# [500 rows x 2 columns]

# %%
lp.ggplot(guesses) + lp.geom_bar(lp.aes(x="Guessed P(H)"))
# Out:
# <html lang="en">
#    <head>
#        <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.5.1/js-package/distr/lets-plot.min.js"></script>
#    </head>
#    <body>
#           <div id="130SXu"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"Guessed P(H)"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[68.0,56.0,65.0,65.0,76.0,14.0,6.0,28.0,51.0,29.0,22.0,5.0,1.0,8.0,4.0,1.0,1.0],
# "Guessed P(H)":[0.07,0.06,0.09,0.1,0.08,0.13,0.02,0.11,0.05,0.12,0.04,0.03,0.17,0.14,0.01,0.15,0.16]
# }
# }],
# "metainfo_list":[]
# };
#        var plotContainer = document.getElementById("130SXu");
#        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#    </script>
#    </body>
# </html>

# %% [markdown]
# #### What happens if we do a lot more tosses per trial?
#
# Let's do 10,000 tosses per trial!

# %%
num_retries = 500
num_tosses = 10000

tosses = pd.DataFrame(
    np.random.choice(
        ["H", "T"], size=(num_retries, num_tosses), p=[p_heads, 1 - p_heads]
    ),
    columns=[f"Toss {i}" for i in range(1, num_tosses + 1)],
    index=[f"Try #{i}" for i in range(1, num_retries + 1)],
)

guesses = (tosses == "H").sum(axis=1).to_frame("Number of Heads")
guesses["Guessed P(H)"] = guesses["Number of Heads"] / num_tosses

lp.ggplot(guesses) + lp.geom_bar(lp.aes(x="Guessed P(H)")) + lp.xlim(0.01, 0.4)
# Out:
# <html lang="en">
#    <head>
#        <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.5.1/js-package/distr/lets-plot.min.js"></script>
#    </head>
#    <body>
#           <div id="p6E39w"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.01,0.4]
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"Guessed P(H)"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[7.0,1.0,6.0,6.0,4.0,6.0,6.0,10.0,3.0,5.0,1.0,5.0,1.0,9.0,4.0,4.0,1.0,6.0,9.0,2.0,8.0,5.0,4.0,4.0,2.0,7.0,4.0,1.0,5.0,2.0,6.0,2.0,5.0,6.0,1.0,7.0,5.0,4.0,6.0,5.0,3.0,2.0,3.0,4.0,1.0,5.0,4.0,2.0,2.0,2.0],
# "Guessed P(H)":[0.2146,0.2046,0.2164,0.2105,0.2148,0.2166,0.2145,0.209,0.2152,0.2101,0.2183,0.2157,0.2044,0.2142,0.213,0.2119,0.205,0.2084,0.2123,0.2159,0.21,0.2091,0.2174,0.2088,0.2075,0.2115,0.2158,0.2052,0.2122,0.2073,0.2108,0.216,0.2124,0.2144,0.2061,0.2102,0.2126,0.217,0.2162,0.2107,0.2113,0.2125,0.2197,0.2132,0.2198,0.214,0.2141,0.2217,0.2117,0.2188]
# }
# }],
# "metainfo_list":[],
# "computation_messages":["sampling_pick(n=50) was applied to [bar/count stat] layer"]
# };
#        var plotContainer = document.getElementById("p6E39w");
#        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#    </script>
#    </body>
# </html>

# %% [markdown]
# #### What happens if we do many more trials?
#
# Let's keep doing 100 experiments per trial but we now do 50,000 trials!

# %%
num_retries = 50000
num_tosses = 100

tosses = pd.DataFrame(
    np.random.choice(
        ["H", "T"], size=(num_retries, num_tosses), p=[p_heads, 1 - p_heads]
    ),
    columns=[f"Toss {i}" for i in range(1, num_tosses + 1)],
    index=[f"Try #{i}" for i in range(1, num_retries + 1)],
)

guesses = (tosses == "H").sum(axis=1).to_frame("Number of Heads")
guesses["Guessed P(H)"] = guesses["Number of Heads"] / num_tosses

lp.ggplot(guesses) + lp.geom_bar(lp.aes(x="Guessed P(H)")) + lp.xlim(0.1, 0.6)
# Out:
# <html lang="en">
#    <head>
#        <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.5.1/js-package/distr/lets-plot.min.js"></script>
#    </head>
#    <body>
#           <div id="MbTbNl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.1,0.6]
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"Guessed P(H)"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[4351.0,4424.0,2923.0,4898.0,1577.0,4702.0,2344.0,641.0,2179.0,3696.0,1818.0,3138.0,4660.0,988.0,1243.0,3690.0,863.0,530.0,335.0,205.0,308.0,110.0,167.0,60.0,31.0,6.0,52.0,21.0,6.0,1.0],
# "Guessed P(H)":[0.19,0.23,0.17,0.21,0.15,0.22,0.26,0.13,0.16,0.24,0.27,0.25,0.2,0.14,0.28,0.18,0.29,0.3,0.12,0.32,0.31,0.33,0.11,0.1,0.35,0.37,0.34,0.36,0.38,0.39]
# }
# }],
# "metainfo_list":[]
# };
#        var plotContainer = document.getElementById("MbTbNl");
#        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#    </script>
#    </body>
# </html>

# %% [markdown]
# #### We've ended up with not one guess, but many 'possible' guesses
#
# - Some guesses happen more often in our repeated experiment - they are more likely to happen
# - The P(H) guesses which happen more often are more likely - by definition, since they happen more often.

# %% [markdown]
# #### For this coin flipping experiment, n(H)/n(H) + n(T) is the 'best' guess - it is the most likely
#
# This way of picking a guess is called the *Maximum Likelihood Estimation* and there are ways to derive the value of it!
